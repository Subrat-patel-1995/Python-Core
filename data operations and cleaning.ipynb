# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #creating a dataframe from a dictionary

# %%
df=pd.DataFrame({"age":[12,13,14,15,12,14],"height":[120,123,145,136,125,146],"weight":[56,78,87,90,82,76]})
df
# Out:
#    age  height  weight
# 0   12     120      56
# 1   13     123      78
# 2   14     145      87
# 3   15     136      90
# 4   12     125      82
# 5   14     146      76

# %%
df.head()#top 5 default
# Out:
#    age  height  weight
# 0   12     120      56
# 1   13     123      78
# 2   14     145      87
# 3   15     136      90
# 4   12     125      82

# %%
df.tail(3)
# Out:
#    age  height  weight
# 3   15     136      90
# 4   12     125      82
# 5   14     146      76

# %%
df.shape
#return tuple of rows and columns
# Out:
# (6, 3)

# %%
df.shape[1]#because it is a tuple
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     6 non-null      int64
#  1   height  6 non-null      int64
#  2   weight  6 non-null      int64
# dtypes: int64(3)
# memory usage: 272.0 bytes

# %%
df.describe()
# Out:
#              age     height     weight
# count   6.000000    6.00000   6.000000
# mean   13.333333  132.50000  78.166667
# std     1.211060   11.43241  12.073387
# min    12.000000  120.00000  56.000000
# 25%    12.250000  123.50000  76.500000
# 50%    13.500000  130.50000  80.000000
# 75%    14.000000  142.75000  85.750000
# max    15.000000  146.00000  90.000000

# %%
df.describe().T
# Out:
#         count        mean        std    min     25%    50%     75%    max
# age       6.0   13.333333   1.211060   12.0   12.25   13.5   14.00   15.0
# height    6.0  132.500000  11.432410  120.0  123.50  130.5  142.75  146.0
# weight    6.0   78.166667  12.073387   56.0   76.50   80.0   85.75   90.0

# %%
df.T
# Out:
#           0    1    2    3    4    5
# age      12   13   14   15   12   14
# height  120  123  145  136  125  146
# weight   56   78   87   90   82   76

# %%
import seaborn as sns

# %%
df1=sns.load_dataset("titanic")

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.isna().sum()# number of null vaues
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
(df1.isna().sum()/df1.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df1["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df1["age"].mean()
# Out:
# 29.69911764705882

# %%
df1["age"].median()
# Out:
# 28.0

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1["age"].fillna(df1["age"].median(),inplace=True)

# %%
df1["age"].isna().sum()
# Out:
# 0

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1["embarked"].unique()# categorical data
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df1["embarked"].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
df1["embarked"].fillna(df1["embarked"].mode()[0],inplace=True)

# %%
df1.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df1["age"].value_counts()
# Out:
# 28.00    202
# 24.00     30
# 22.00     27
# 18.00     26
# 19.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: age, Length: 88, dtype: int64

# %%
df1["embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
df1["alive"].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
df1["survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
df1["alive"].nunique()
# Out:
# 2

# %%
df1["alive"].count()
# Out:
# 891

# %%
df1["alive"].value_counts("x")
# Out:
# no     0.616162
# yes    0.383838
# Name: alive, dtype: float64

# %%
(df1["alive"].value_counts()[0]/df1["alive"].count())*100
# Out:
# 61.61616161616161

# %%
from scipy import stats

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df1["fare"]);

# %%
iqr=stats.iqr(df1["fare"])
iqr
# Out:
# 23.0896

# %%
df1["fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
a=31+1.5*iqr

# %%
df1[df1["fare"]>a]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 31          1       1  female  28.0      1      0  146.5208        C  First
# 34          0       1    male  28.0      1      0   82.1708        C  First
# 52          1       1  female  49.0      1      0   76.7292        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 846         0       3    male  28.0      8      2   69.5500        S  Third
# 849         1       1  female  28.0      1      0   89.1042        C  First
# 856         1       1  female  45.0      1      1  164.8667        S  First
# 863         0       3  female  28.0      8      2   69.5500        S  Third
# 879         1       1  female  56.0      0      1   83.1583        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
len(df1[df1["fare"]>a])
# Out:
# 116

# %%
# !pip install jupyterthemes

# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
